# %%
import timecorr as tc
import ipyvolume
import numpy as np
from scipy.linalg import toeplitz
from scipy.spatial.distance import squareform, cdist, pdist
import seaborn as sns
from matplotlib import pyplot as plt
import hypertools as hyp

# %matplotlib inline
# Out:
# /usr/local/Cellar/python/3.6.5_1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/local/Cellar/python/3.6.5_1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1016f327fb86> in <module>()
# ----> 1 import timecorr as tc
#       2 import ipyvolume
#       3 import numpy as np
#       4 from scipy.linalg import toeplitz
#       5 from scipy.spatial.distance import squareform, cdist, pdist
#
# /Users/jeremy/Library/Python/3.6/lib/python/site-packages/timecorr/__init__.py in <module>()
# ...

# %%
K = toeplitz(np.arange(1, -0.1, -0.1))
sK = tc.mat2vec(K)
X = tc.simulate.generate_data(sK, T=1000)

# %%
corrs = tc.timecorr(X, weights_function=tc., weights_params=None)

# %%
sns.heatmap(corrs)

# %%
ave_corrs = 1 - squareform(pdist(X.T, 'correlation'))

# %%
ipyvolume.volshow(tc.vec2mat(corrs), lighting=True, level=np.linspace(0, 1, 11))
# Out:
# Figure(anglex=2.183454027561001, angley=-0.7640086020966926, anglez=1.33267748504127, camera_center=[0.0, 0.0,…

# %%
sns.heatmap(np.squeeze(tc.vec2mat(corrs)[:, :, 100]))

# %%
tc.vec2mat(corrs)
# Out:
# array([[[ 0.76159416,  0.76159416,  0.76159416, ...,  0.76159416,
#           0.76159416,  0.76159416],
#         [ 0.71293544,  0.71284511,  0.71277718, ...,  0.71339977,
#           0.7136052 ,  0.71379583],
#         [ 0.66039055,  0.65940754,  0.65848911, ...,  0.66870662,
#           0.6687376 ,  0.6687801 ],
#         ...,
#         [ 0.12055975,  0.11647098,  0.11297706, ...,  0.15388645,
#           0.1527268 ,  0.15176645],
#         [ 0.00933028,  0.00624919,  0.0040285 , ...,  0.04655989,
#           0.04569716,  0.04499688],
#         [-0.04257921, -0.0432861 , -0.04376262, ..., -0.04509467,
#          -0.04644137, -0.04746993]],
#
#        [[ 0.71293544,  0.71284511,  0.71277718, ...,  0.71339977,
#           0.7136052 ,  0.71379583],
#         [ 0.76159416,  0.76159416,  0.76159416, ...,  0.76159416,
#           0.76159416,  0.76159416],
#         [ 0.71703732,  0.71670987,  0.71636437, ...,  0.7187501 ,
#           0.71874976,  0.7187431 ],
#         ...,
# ...

# %%
raise ValueError('test')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-6d7f71609539> in <module>()
# ----> 1 raise ValueError('test')
#
# ValueError: test

# %%
np.zeros(3)
# Out:
# array([0., 0., 0.])

# %%
x = np.arange(-10, 10, 0.01)

# %%
f1 = np.sqrt(x ** 2)
f2 = (np.sqrt(x) ** 2)

# %%
plt.plot(x, f1)
plt.show()

plt.figure()
plt.plot(x, f2)
