# %%
import timecorr as tc
import ipyvolume
import numpy as np
from scipy.linalg import toeplitz
from scipy.spatial.distance import squareform, cdist, pdist
import seaborn as sns
from matplotlib import pyplot as plt
import hypertools as hyp

# %matplotlib inline

# %%
K = toeplitz(np.arange(1, -0.1, -0.1))
sK = tc.mat2vec(K)
X = tc.simulate.generate_data(sK, T=1000)

# %%
corrs = tc.timecorr(X)

# %%
ave_corrs = 1 - squareform(pdist(X.T, 'correlation'))

# %%
sns.heatmap(ave_corrs)

# %%
tc.vec2mat(corrs).shape
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-89-55430d7bf8dd> in <module>()
# ----> 1 tc.vec2mat(corrs).shape
#
# ~/timecorr/timecorr/helpers.py in vec2mat(v)
#     338 def vec2mat(v):
#     339     x = int(0.5*(np.sqrt(8*len(v) + 1) - 1))
# --> 340     return sd.squareform(v[x:]) + np.diag(v[0:x])
#     341
#     342
#
# /usr/local/lib/python3.6/site-packages/scipy/spatial/distance.py in squareform(X, force, checks)
#    2062     elif len(s) == 2:
#    2063         if s[0] != s[1]:
# -> 2064             raise ValueError('The matrix argument must be square.')
#    2065         if checks:
#    2066             is_valid_dm(X, throw=True, name='X')
#
# ValueError: The matrix argument must be square.

# %%
# ?tc.vec2mat

# %%
np.ndim(corrs[0, :])
# Out:
# 1

# %%
x = np.arange(-10, 10, 0.01)

# %%
f1 = np.sqrt(x ** 2)
f2 = (np.sqrt(x) ** 2)

# %%
plt.plot(x, f1)
plt.show()

plt.figure()
plt.plot(x, f2)
