# %%
import numpy as np
import os
from scipy.spatial.distance import squareform, cdist
import seaborn as sns
from timecorr.simulate import generate_multisubject_data
import timecorr as tc
# %matplotlib inline

# %% [markdown]
# ## simulate some data with default stuff

# %%
sim_data = generate_multisubject_data()

# %%
sim_data
# Out:
# [array([[-3.4198524 , -0.71699651, -0.15571243, ...,  2.83511406,
#          -1.43602282,  2.76240225],
#         [-0.67131239, -0.12700369,  1.89424355, ...,  3.16924757,
#           0.02607622,  2.66764174],
#         [ 2.25067088,  2.59827249, -2.59012603, ..., -0.13475075,
#          -0.80904733,  0.04550348],
#         ...,
#         [-4.65028535,  1.46512383,  1.75424649, ..., -2.53276778,
#           5.33482171,  1.25963948],
#         [-2.08453974, -2.92147546,  0.22686658, ...,  1.43971941,
#           0.57724725,  2.52032094],
#         [ 2.27902018,  4.64051837, -3.23080267, ...,  6.16169679,
#          -0.54617843,  1.90552785]]),
#  array([[ 2.95236373,  1.92498201, -1.79550981, ..., -0.04990552,
#           0.86491259, -1.77292476],
#         [ 2.55823768,  1.43009813, -1.82961864, ..., -3.13408908,
#          -0.4791351 ,  3.5884538 ],
#         [ 3.71768025,  1.51857745,  2.91957021, ..., -5.38678379,
#           2.0343091 ,  2.14881493],
#         ...,
# ...

# %%
recovered_covs = tc.timecorr(sim_data, mode='across')

# %%
recovered_covs
# Out:
# array([[-9.64195116e-03,  6.68216343e-03, -5.91087639e-03, ...,
#          5.72164023e-03,  2.96226093e-03,  2.87724842e-07],
#        [-9.99840082e-03,  6.25746334e-03, -5.76832948e-03, ...,
#          5.16823405e-03,  2.66451595e-03, -2.46550258e-05],
#        [-9.77463198e-03,  6.32385378e-03, -6.22480764e-03, ...,
#          5.29284614e-03,  2.64322495e-03,  1.44741242e-04],
#        ...,
#        [-6.48770065e-03,  4.40040877e-03, -5.35391857e-03, ...,
#          2.21744521e-03, -7.68213988e-03, -7.85340335e-03],
#        [-6.40203453e-03,  4.17456529e-03, -5.45535505e-03, ...,
#          2.16575913e-03, -7.65983919e-03, -7.59560231e-03],
#        [-6.34434457e-03,  3.09570774e-03, -5.19239811e-03, ...,
#          2.12800207e-03, -7.77307370e-03, -7.66554682e-03]])
