# %%
import numpy as np
import os
from scipy.spatial.distance import squareform, cdist
import seaborn as sns
from timecorr.simulate import simulate_timecorr_data
import timecorr as tc
# %matplotlib inline

# %% [markdown]
# ## simulate some data with default stuff

# %%
sim_data = simulate_timecorr_data()

# %%
sim_data
# Out:
# [array([[ 8.8028154 , -1.38465005,  3.5008068 , ...,  8.8782107 ,
#           1.20204271,  0.51647303],
#         [ 3.42683434, -3.20410924, -3.83087481, ...,  0.240584  ,
#          -2.23039245, -3.14673351],
#         [-0.46009815,  1.77428693,  1.30447068, ...,  0.53397135,
#           5.23489084, -2.17357994],
#         ...,
#         [-4.17782531,  3.11089572,  0.42555195, ..., -1.76456066,
#           1.02638907, -2.96970374],
#         [-2.93715268,  1.78097635,  2.41428619, ...,  0.26585428,
#           1.48800007,  1.80869698],
#         [ 1.40759068, -1.64302413,  2.17840371, ..., -2.91442026,
#           0.9288353 ,  3.56948582]]),
#  array([[-2.37109328,  1.25846684, -5.91852651, ...,  3.42516413,
#          -3.87371424,  4.29249132],
#         [-1.9227869 , -2.00931537, -1.02009906, ...,  0.2565364 ,
#           0.1782284 ,  1.64992348],
#         [-0.16006535,  1.60091327, -6.48732696, ...,  4.08734873,
#          -5.88750287,  3.15521316],
#         ...,
#         [-7.70673332, -8.20243572,  0.40821146, ..., -2.77149501,
#          -4.99116083,  1.3054645 ],
#         [ 1.28542028, -6.35098269,  1.63907008, ...,  1.11494541,
#          -2.87077035, -1.19878185],
#         [-1.89049643, -3.07790398, -5.26229724, ...,  3.14130077,
#          -0.6029637 , -0.2209019 ]]),
#  array([[-4.0584338 ,  3.40476897, -1.5621416 , ..., -0.31754221,
#           1.70328621, -3.43750932],
#         [ 3.07776103, -2.84597088,  1.9878321 , ..., -6.05135066,
#           0.80285378, -0.50833377],
#         [ 3.73670218,  0.16142136, -4.95637038, ...,  0.70973048,
#          -2.90904486, -1.584122  ],
#         ...,
#         [-4.40850303, -3.03653469, -1.85949443, ..., -1.58891736,
#          -1.62954258,  1.73032958],
#         [ 0.57461828, -1.49860758,  2.61112377, ...,  5.22357345,
#           4.64315975,  1.88611346],
#         [-1.53006184, -4.01990118, -3.84629038, ...,  7.24973137,
#          -1.93601823, -0.84529552]]),
#  array([[ 1.76606883, -1.89141174,  5.07581412, ..., -2.33270269,
#           2.09744572, -2.18193177],
#         [ 0.3843972 , -4.68156902,  0.0992622 , ..., -1.62618243,
#          -1.69614204,  0.28589858],
#         [-2.83713629,  1.67783302,  4.6096755 , ...,  1.65182855,
#          -2.71188691,  1.46596627],
#         ...,
#         [ 2.43601932, -3.82932717,  1.55078873, ...,  1.08672687,
#           3.04228122,  3.14210805],
#         [ 1.87237102, -0.92124496,  4.28630394, ..., -3.8611275 ,
#           1.21326481,  2.45365563],
#         [-0.56860989, -2.69854279,  1.26130594, ..., -0.00655201,
#          -0.18903407,  3.16061989]]),
#  array([[-0.34675451,  0.09100797,  2.43334816, ...,  2.2205862 ,
#           1.54410842, -2.46745152],
#         [-4.01997249, -1.63704249, -2.96267972, ..., -0.24530859,
#           2.16283701, -1.57376564],
#         [-3.59104965, -3.11690925,  1.62131845, ..., -3.92643046,
#           0.36639725,  1.08439979],
#         ...,
#         [ 5.22902473,  4.5867376 , -4.97575242, ..., -0.16311753,
#          -3.51373951, -2.77497368],
#         [-0.71608206,  0.62644208, -0.64135999, ...,  4.45019577,
#           2.99181814, -1.15558877],
#         [-4.11671669,  1.1039549 , -0.7758178 , ..., -0.07051145,
#           1.96642837, -0.57978092]])]

# %%
recovered_covs = tc.timecorr(sim_data, mode='across')

# %%
recovered_covs
# Out:
# array([[-9.64195116e-03,  6.68216343e-03, -5.91087639e-03, ...,
#          5.72164023e-03,  2.96226093e-03,  2.87724842e-07],
#        [-9.99840082e-03,  6.25746334e-03, -5.76832948e-03, ...,
#          5.16823405e-03,  2.66451595e-03, -2.46550258e-05],
#        [-9.77463198e-03,  6.32385378e-03, -6.22480764e-03, ...,
#          5.29284614e-03,  2.64322495e-03,  1.44741242e-04],
#        ...,
#        [-6.48770065e-03,  4.40040877e-03, -5.35391857e-03, ...,
#          2.21744521e-03, -7.68213988e-03, -7.85340335e-03],
#        [-6.40203453e-03,  4.17456529e-03, -5.45535505e-03, ...,
#          2.16575913e-03, -7.65983919e-03, -7.59560231e-03],
#        [-6.34434457e-03,  3.09570774e-03, -5.19239811e-03, ...,
#          2.12800207e-03, -7.77307370e-03, -7.66554682e-03]])
